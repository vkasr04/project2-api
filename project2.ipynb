# %% [markdown]
# # Project 2: Web Scraping and API access

# %%
# !pip install beautifulsoup4

# %% [markdown]
# ## Part 1: Explore the html for Wikipedia articles.

# %% [markdown]
# ### A. Using inspect element, copy the html code for a table.

# %% [markdown]
# HTML code for a table from the wikipedia page

# %% [markdown]
# <table class="infobox vcard" style="width:26em"><caption class="infobox-title fn summary">Stephen Curry</caption><tbody><tr><td colspan="2" class="infobox-image"><span class="mw-default-size" typeof="mw:File/Frameless"><a href="/wiki/File:Steph_Curry_P20230117AS-1347_(cropped).jpg" class="mw-file-description"><img alt="Curry during a visit to the White House in 2023" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Steph_Curry_P20230117AS-1347_%28cropped%29.jpg/220px-Steph_Curry_P20230117AS-1347_%28cropped%29.jpg" decoding="async" width="220" height="249" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Steph_Curry_P20230117AS-1347_%28cropped%29.jpg/330px-Steph_Curry_P20230117AS-1347_%28cropped%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Steph_Curry_P20230117AS-1347_%28cropped%29.jpg/440px-Steph_Curry_P20230117AS-1347_%28cropped%29.jpg 2x" data-file-width="668" data-file-height="755"></a></span><div class="infobox-caption">Curry in 2023</div></td></tr><tr><th colspan="2" class="infobox-header" style="background-color: #1D428A; color: #FFFFFF; border: 2.5px solid #FDB927;">No. 30 – Golden State Warriors</th></tr><tr><th scope="row" class="infobox-label">Position</th><td class="infobox-data role"><a href="/wiki/Point_guard" title="Point guard">Point guard</a></td></tr><tr><th scope="row" class="infobox-label">League</th><td class="infobox-data"><a href="/wiki/National_Basketball_Association" title="National Basketball Association">NBA</a></td></tr><tr><th colspan="2" class="infobox-header" style="background-color: #1D428A; color: #FFFFFF; border: 2.5px solid #FDB927;">Personal information</th></tr><tr><th scope="row" class="infobox-label">Born</th><td class="infobox-data"><span style="display:none"> (<span class="bday">1988-03-14</span>) </span>March 14, 1988<span class="noprint ForceAgeToShow"> (age&nbsp;36)</span><br><a href="/wiki/Akron,_Ohio" title="Akron, Ohio">Akron, Ohio</a>, U.S.</td></tr><tr><th scope="row" class="infobox-label">Listed height</th><td class="infobox-data">6&nbsp;ft 2&nbsp;in (1.88&nbsp;m)</td></tr><tr><th scope="row" class="infobox-label">Listed weight</th><td class="infobox-data">185&nbsp;lb (84&nbsp;kg)</td></tr><tr><th colspan="2" class="infobox-header" style="background-color: #1D428A; color: #FFFFFF; border: 2.5px solid #FDB927;">Career information</th></tr><tr><th scope="row" class="infobox-label">High school</th><td class="infobox-data plainlist"><a href="/wiki/Charlotte_Christian_School" title="Charlotte Christian School">Charlotte Christian</a><br>(<a href="/wiki/Charlotte,_North_Carolina" title="Charlotte, North Carolina">Charlotte, North Carolina</a>)</td></tr><tr><th scope="row" class="infobox-label">College</th><td class="infobox-data plainlist"><a href="/wiki/Davidson_Wildcats_men%27s_basketball" title="Davidson Wildcats men's basketball">Davidson</a> (2006–2009)</td></tr><tr><th scope="row" class="infobox-label"><a href="/wiki/NBA_draft" title="NBA draft">NBA draft</a></th><td class="infobox-data"><a href="/wiki/2009_NBA_draft" title="2009 NBA draft">2009</a>: 1st  round, 7th overall pick</td></tr><tr><td colspan="2" class="infobox-full-data">Selected by the <a href="/wiki/Golden_State_Warriors" title="Golden State Warriors">Golden State Warriors</a></td></tr><tr><th scope="row" class="infobox-label">Playing career</th><td class="infobox-data">2009–present</td></tr><tr><th colspan="2" class="infobox-header" style="background-color: #1D428A; color: #FFFFFF; border: 2.5px solid #FDB927;">Career history<link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r
><span class="cite-bracket">[</span>a<span class="cite-bracket">]</span></a></sup> 2022)</li>
# <li>Consensus first-team <a href="/wiki/NCAA_Men%27s_Basketball_All-Americans" title="NCAA Men's Basketball All-Americans">All-American</a> (<a href="/wiki/2009_NCAA_Men%27s_Basketball_All-Americans" title="2009 NCAA Men's Basketball All-Americans">2009</a>)</li>
# <li>Consensus second-team All-American (<a href="/wiki/2008_NCAA_Men%27s_Basketball_All-Americans" title="2008 NCAA Men's Basketball All-Americans">2008</a>)</li>
# <li><a href="/wiki/List_of_NCAA_Division_I_men%27s_basketball_season_scoring_leaders" title="List of NCAA Division I men's basketball season scoring leaders">NCAA season scoring leader</a> (2009)</li>
# <li>2× <a href="/wiki/Southern_Conference_Men%27s_Basketball_Player_of_the_Year" title="Southern Conference Men's Basketball Player of the Year">SoCon Player of the Year</a> (2008, 2009)</li>
# <li>3× First-team All-<a href="/wiki/Southern_Conference" title="Southern Conference">SoCon</a> (2007–2009)</li>
# <li>No. 30 <a href="/wiki/Davidson_Wildcats_men%27s_basketball#Retired_numbers" title="Davidson Wildcats men's basketball">retired by Davidson Wildcats</a></li></ul>
# </td></tr><tr style="display:none"><th colspan="2">
# </th></tr><tr><td colspan="2" class="infobox-full-data"><span style="font-weight:bold"><a rel="nofollow" class="external text" href="https://www.nba.com/player/201939">Stats</a>&nbsp;<span class="mw-valign-text-top noprint" typeof="mw:File/Frameless"><a href="https://www.wikidata.org/wiki/Q352159#P3647" title="Edit this at Wikidata"><img alt="Edit this at Wikidata" src="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png" decoding="async" width="10" height="10" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/15px-OOjs_UI_icon_edit-ltr-progressive.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png 2x" data-file-width="20" data-file-height="20"></a></span> at NBA.com</span></td></tr><tr><td colspan="2" class="infobox-full-data"><span style="font-weight:bold"><a rel="nofollow" class="external text" href="https://www.basketball-reference.com/players/c/curryst01.html">Stats</a>&nbsp;<span class="mw-valign-text-top noprint" typeof="mw:File/Frameless"><a href="https://www.wikidata.org/wiki/Q352159#P2685" title="Edit this at Wikidata"><img alt="Edit this at Wikidata" src="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png" decoding="async" width="10" height="10" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/15px-OOjs_UI_icon_edit-ltr-progressive.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png 2x" data-file-width="20" data-file-height="20"></a></span> at Basketball-Reference.com</span></td></tr><tr><td colspan="2" class="infobox-below" style="background-color: #1D428A; color: #FFFFFF;"><div class="mw-collapsible mw-made-collapsible" style="text-align:center; font-size:95%"><button type="button" class="mw-collapsible-toggle mw-collapsible-toggle-default" aria-expanded="true" tabindex="0"><span class="mw-collapsible-text">hide</span></button>
#     <div class="skin-nightmode-reset-color" style="line-height:1.6em; background-color:#ccf; font-size:105%; background-color: #DCDCDC; color: #000000;"><div style="margin:0 4em;">Medals</div></div>
#     <div class="mw-collapsible-content" style="font-size:105%"><style data-mw-deduplicate="TemplateStyles:r1151960987">body.skin-minerva .mw-parser-output .infobox table{display:table}body.skin-minerva .mw-parser-output .infobox caption{display:table-caption}</style>
# <table class="skin-nightmode-reset-color" style="width:100%; background-color:#f9f9f9; color:#000000; font-weight:normal">
# <tbody><tr>
# <td colspan="2" style="padding:0">
# </td></tr>
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#eeeeee;color:inherit;">Men's <a href="/wiki/Basketball" title="Basketball">basketball</a>
# </th></tr>
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#eeeeee;color:inherit;" class="adr">Representing <span class="country-name">the <span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5d/Flag_of_the_United_States_%2823px%29.png/23px-Flag_of_the_United_States_%2823px%29.png" decoding="async" width="23" height="13" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5d/Flag_of_the_United_States_%2823px%29.png/35px-Flag_of_the_United_States_%2823px%29.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5d/Flag_of_the_United_States_%2823px%29.png/46px-Flag_of_the_United_States_%2823px%29.png 2x" data-file-width="69" data-file-height="39"></span></span>&nbsp;</span><a href="/wiki/United_States" title="United States">United States</a></span>
# </th></tr>
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#cccccc;color:inherit;"><a href="/wiki/Olympic_Games" title="Olympic Games">Olympic Games</a>
# </th></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;color:inherit;"><span typeof="mw:File"><span title="Gold medal – first place"><img alt="Gold medal – first place" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/16px-Gold_medal_icon_%28G_initial%29.svg.png" decoding="async" width="16" height="16" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/24px-Gold_medal_icon_%28G_initial%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/32px-Gold_medal_icon_%28G_initial%29.svg.png 2x" data-file-width="16" data-file-height="16"></span></span></td>
# <td style="text-align:center;vertical-align:middle;"><span class="nowrap"><a href="/wiki/Basketball_at_the_2024_Summer_Olympics_%E2%80%93_Men%27s_tournament" title="Basketball at the 2024 Summer Olympics – Men's tournament">2024 Paris</a></span></td>
# <td style="text-align:center;vertical-align:middle;"><a href="/wiki/2024_United_States_men%27s_Olympic_basketball_team" title="2024 United States men's Olympic basketball team">Team</a>
# </td></tr>
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#cccccc;color:inherit;"><a href="/wiki/FIBA_Basketball_World_Cup" title="FIBA Basketball World Cup">FIBA World Cup</a>
# </th></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;color:inherit;"><span typeof="mw:File"><span title="Gold medal – first place"><img alt="Gold medal – first place" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/16px-Gold_medal_icon_%28G_initial%29.svg.png" decoding="async" width="16" height="16" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/24px-Gold_medal_icon_%28G_initial%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/32px-Gold_medal_icon_%28G_initial%29.svg.png 2x" data-file-width="16" data-file-height="16"></span></span></td>
# <td style="text-align:center;vertical-align:middle;"><span class="nowrap"><a href="/wiki/2010_FIBA_World_Championship" title="2010 FIBA World Championship">2010 Turkey</a> </span></td>
# <td style="text-align:center;vertical-align:middle;"><a href="/wiki/2010_United_States_men%27s_FIBA_World_Championship_team" title="2010 United States men's FIBA World Championship team">Team</a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;color:inherit;"><span typeof="mw:File"><span title="Gold medal – first place"><img alt="Gold medal – first place" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/16px-Gold_medal_icon_%28G_initial%29.svg.png" decoding="async" width="16" height="16" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/24px-Gold_medal_icon_%28G_initial%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/32px-Gold_medal_icon_%28G_initial%29.svg.png 2x" data-file-width="16" data-file-height="16"></span></span></td>
# <td style="text-align:center;vertical-align:middle;"><span class="nowrap"><a href="/wiki/2014_FIBA_Basketball_World_Cup" title="2014 FIBA Basketball World Cup">2014 Spain</a> </span></td>
# <td style="text-align:center;vertical-align:middle;"><a href="/wiki/2014_United_States_FIBA_Basketball_World_Cup_team" title="2014 United States FIBA Basketball World Cup team">Team</a>
# </td></tr>
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#cccccc;color:inherit;"><a href="/wiki/FIBA_Under-19_Basketball_World_Cup" title="FIBA Under-19 Basketball World Cup">FIBA U-19 World Cup</a>
# </th></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;color:inherit;"><span typeof="mw:File"><span title="Silver medal – second place"><img alt="Silver medal – second place" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/91/Silver_medal_icon_%28S_initial%29.svg/16px-Silver_medal_icon_%28S_initial%29.svg.png" decoding="async" width="16" height="16" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/91/Silver_medal_icon_%28S_initial%29.svg/24px-Silver_medal_icon_%28S_initial%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/91/Silver_medal_icon_%28S_initial%29.svg/32px-Silver_medal_icon_%28S_initial%29.svg.png 2x" data-file-width="16" data-file-height="16"></span></span></td>
# <td style="text-align:center;vertical-align:middle;"><span class="nowrap"><a href="/wiki/2007_FIBA_Under-19_World_Championship" title="2007 FIBA Under-19 World Championship">2007 Serbia</a> </span></td>
# <td style="text-align:center;vertical-align:middle;"><a href="/wiki/2007_FIBA_Under-19_World_Championship#Medal_rosters" title="2007 FIBA Under-19 World Championship">Team</a>
# </td></tr></tbody></table>
# </div></div></td></tr></tbody></table>

# %% [markdown]
# ### B. Using inspect element, find the html syntax for a link.

# %% [markdown]
# HTML link code from the wikipedia page:

# %% [markdown]
# <a href="/wiki/Golden_State_Warriors" title="Golden State Warriors">Golden State Warriors</a>

# %% [markdown]
# ### C. Using inspect element, find the html syntax for linking an image

# %% [markdown]
# HTML code for linking a image from the wikipedia page:

# %% [markdown]
# <a href="/wiki/File:Steph_Curry_P20230117AS-1347_(cropped).jpg">
#     <img src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Steph_Curry_P20230117AS-1347_%28cropped%29.jpg/220px-Steph_Curry_P20230117AS-1347_%28cropped%29.jpg" alt="Curry during a visit to the White House in 2023">
# </a>

# %% [markdown]
# <a href="/wiki/File:Steph_Curry_P20230117AS-1347_(cropped).jpg">
#     <img src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Steph_Curry_P20230117AS-1347_%28cropped%29.jpg/220px-Steph_Curry_P20230117AS-1347

# %% [markdown]
# ## Part 2: Explore one Wikipedia page with the beautifulsoup package

# %%
import bs4
import requests
import pandas as pd

# %%
#save and print the text content of a page with all tags removed
from bs4 import BeautifulSoup
url = "https://en.wikipedia.org/wiki/Stephen_Curry"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
page_text = soup.get_text()
print(page_text)
# Out:
# Stephen Curry - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
#  Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# Early life
#
#
#
#
#
#
#
#
# 2
# College career
#
#
#
#
# Toggle College career subsection
#
#
#
#
#
# 2.1
# Freshman season
#
#
#
#
#
#
#
#
# ...

# %%
#download an image with beautifulsoup and save it in this repository
image_url = image['src']
if image_url.startswith('//'):
    image_url = 'https:' + image_url
elif image_url.startswith('/'):
    image_url = 'https://en.wikipedia.org' + image_url  

# Step 2: Download and save the image
img_data = requests.get(image_url).content
with open('stephen_curry_image.jpg', 'wb') as img_file:
    img_file.write(img_data)

print("Image downloaded: 'stephen_curry_image.jpg'.")
# Out:
# Image downloaded: 'stephen_curry_image.jpg'.

# %% [markdown]
# Used ChatGPT help for explanations and code debugging and code snippets, ran into a lot of problems with getting the links and getting the first 100 characters.

# %%
import random
#find all the links in a page with beautifulsoup
#print the first 100 characters of ten of these links
base_url = "https://en.wikipedia.org"
valid_links = []
for link in links:
    href = link['href']
    if href.startswith('#'):
        continue
    
    # Handle relative URLs
    if href.startswith('/'):
        href = base_url + href
    elif href.startswith('//'):
        href = 'https:' + href
    
    valid_links.append(href)

random_links = random.sample(valid_links, 10)

for i, href in enumerate(random_links):
    try:
        linked_page_response = requests.get(href)
        linked_page_soup = BeautifulSoup(linked_page_response.text, 'html.parser')
        
        linked_page_text = linked_page_soup.get_text()[:100]
        print(f"Random Link {i+1}: {href}")
        print(f"Content: {linked_page_text}\n")
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {href}: {e}")
# Out:
# Random Link 1: https://en.wikipedia.org/wiki/Ernie_Calverley
# Content:
#
#
#
# Ernie Calverley - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
# Random Link 2: https://en.wikipedia.org/wiki/Brian_Grant
# Content:
#
#
#
# Brian Grant - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main me
#
# Random Link 3: https://www.nba.com/warriors/gameday/20210412/recap
# Content:
#
# Stephen Curry Makes History in Win Over Nuggets | NBA.com
#
# Random Link 4: https://en.wikipedia.org/wiki/Tiger_Woods
# Content:
#
#
#
# Tiger Woods - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
#
# Random Link 5: https://en.wikipedia.org/wiki/NBA_draft
# Content:
#
#
#
# NBA draft - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
# ...

# %% [markdown]
# ## Part 3: Downloading scripts

# %%
scripts=pd.read_csv('pudding_data.csv')

# %%
scripts
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %%
#using the links in the "link" column, download the first 1000 characters of each script
#use requests and bs4, remember to remove all html tags

def fetch_script_text(url):
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            response.encoding = response.apparent_encoding
            soup = BeautifulSoup(response.text, 'html.parser')
            text = soup.get_text(separator=' ', strip=True)
            return text.encode('utf-8', 'replace').decode('utf-8')[:1000]
        else:
            return "Error: Non-200 status code"
    except Exception as e:
        return f"Error: {e}"

# %%
#add a new column to the df with the text downloaded
#save this new dataframe as "pudding_texts.csv"

scripts['script_text'] = scripts['link'].apply(lambda x: fetch_script_text(x) if pd.notna(x) else "No link provided")

scripts.to_csv('pudding_texts.csv', index=False)

scripts.head()
# Out:
#      imdb_id  script_id             title  year  gross (inflation-adjusted)  \
# 0  tt0019777       4031     The Cocoanuts  1929                         NaN
# 1  tt0021884       8521      Frankenstein  1931                       298.0
# 2  tt0022054       1086   The Last Flight  1931                         NaN
# 3  tt0022626       1631  American Madness  1932                         NaN
# 4  tt0022958       2438       Grand Hotel  1932                         NaN
#
#                                                 link  \
# 0  http://www.pages.drexel.edu/~ina22/splaylib/Sc...
# 1  Frankenstein (Florey & Fort) [1931-5-23] [Scan...
# 2  film_20100519/all_imsdb_05_19_10/Last-Flight,-...
# 3  http://www.imsdb.com/Movie Scripts/American Ma...
# 4  http://www.imsdb.com/Movie Scripts/Grand Hotel...
#
#                                          script_text
# 0  Error: HTTPConnectionPool(host='www.pages.drex...
# 1  Error: Failed to parse: Frankenstein (Florey &...
# ...

# %% [markdown]
# ## Part 4: TMDB database

# %% [markdown]
# #### Browse the documentation at https://developer.themoviedb.org/reference/intro/getting-started. Create an account to authenticate

# %%
#create a dataset of the movies in theaters now. Include metadata fields you are interested in. 
import requests

url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyYWQyNmFmYTFiZTI4ODcxY2ViMGU2NmEwZDMyYjM4OSIsIm5iZiI6MTcyODkzOTg0OC42NzI4NzcsInN1YiI6IjY3MGQ4NjI1NDJlMTM5MWM1NjY2Y2I5MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.jr6_v0fUC9HuatXxOZBEfekxgau4v-03aoJJvCByNQM"
}

response = requests.get(url, headers=headers)

# %%
movies_data = response.json()
print(movies_data)
# Out:
# {'dates': {'maximum': '2024-10-16', 'minimum': '2024-09-04'}, 'page': 1, 'results': [{'adult': False, 'backdrop_path': '/xi1VSt3DtkevUmzCx2mNlCoDe74.jpg', 'genre_ids': [35, 14, 27], 'id': 917496, 'original_language': 'en', 'original_title': 'Beetlejuice Beetlejuice', 'overview': "After a family tragedy, three generations of the Deetz family return home to Winter River. Still haunted by Betelgeuse, Lydia's life is turned upside down when her teenage daughter, Astrid, accidentally opens the portal to the Afterlife.", 'popularity': 3803.758, 'poster_path': '/kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg', 'release_date': '2024-09-04', 'title': 'Beetlejuice Beetlejuice', 'video': False, 'vote_average': 7.189, 'vote_count': 1244}, {'adult': False, 'backdrop_path': '/3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg', 'genre_ids': [878, 53, 18, 27], 'id': 1125510, 'original_language': 'es', 'original_title': 'El hoyo 2', 'overview': 'After a mysterious leader imposes his law in a brutal system of vertical cells, a new ar
# ...

# %%
#download the movie posters for 10 of these movies and save them to this repository
import os
if 'results' in movies_data:
    movies = movies_data['results']
else:
    print("Error: Could not find 'results' in the response.")
    movies = []

os.makedirs("movie_posters", exist_ok=True)

movie_list = []
for i, movie in enumerate(movies[:10]):
    movie_metadata = {
        "title": movie['title'],
        "release_date": movie['release_date'],
        "overview": movie['overview'],
        "vote_average": movie['vote_average'],
        "poster_path": f"https://image.tmdb.org/t/p/w500{movie['poster_path']}"  # Full URL to the poster
    }
    
    movie_list.append(movie_metadata)
    
    poster_url = movie_metadata['poster_path']
    poster_response = requests.get(poster_url)
    
    if poster_response.status_code == 200:
        with open(f"movie_posters/{movie['title'].replace('/', '')}.jpg", 'wb') as file:
            file.write(poster_response.content)
        print(f"Downloaded poster for: {movie['title']}")
    else:
        print(f"Failed to download poster for: {movie['title']}")
        
print(movie_list[0])
# Out:
# Downloaded poster for: Beetlejuice Beetlejuice
# Downloaded poster for: The Platform 2
# Downloaded poster for: The Substance
# Downloaded poster for: Terrifier 3
# Downloaded poster for: The Wild Robot
# Downloaded poster for: Project Silence
# Downloaded poster for: The Crow
# Downloaded poster for: The Bad Guys: Haunted Heist
# Downloaded poster for: Trouble
# Downloaded poster for: Speak No Evil
# {'title': 'Beetlejuice Beetlejuice', 'release_date': '2024-09-04', 'overview': "After a family tragedy, three generations of the Deetz family return home to Winter River. Still haunted by Betelgeuse, Lydia's life is turned upside down when her teenage daughter, Astrid, accidentally opens the portal to the Afterlife.", 'vote_average': 7.189, 'poster_path': 'https://image.tmdb.org/t/p/w500/kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg'}
